# %%
# azureml-core of version 1.0.72 or higher is required
# azureml-dataprep[pandas] of version 1.1.34 or higher is required
from azureml.core import Workspace, Dataset

subscription_id = 'be34845d-449d-4f47-89be-d6776438dd0e'
resource_group = 'cmr'
workspace_name = 'cmrmlo'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='netflix')
dataset.to_pandas_dataframe()
# Out:
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe'}
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe', 'activityApp': 'TabularDataset'}
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/mlflow/__init__.py:41: UserWarning: Versions of mlflow (3.8.1) and child packages mlflow-skinny (3.5.0) are different. This may lead to unexpected behavior. Please install the same version of all MLflow packages.
#   mlflow.mismatch._check_version_mismatch()
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             None
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             None
# 4         s5  TV Show           Kota Factory             None
# ...      ...      ...                    ...              ...
# 8804   s8803    Movie                 Zodiac    David Fincher
# 8805   s8804  TV Show            Zombie Dumb             None
# 8806   s8805    Movie             Zombieland  Ruben Fleischer
# 8807   s8806    Movie                   Zoom     Peter Hewitt
# 8808   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                  None  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           None
# 3                                                  None           None
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8804  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8805                                               None           None
# 8806  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8807  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8808  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021        2020.0  PG-13     90 min
# 1     September 24, 2021        2021.0  TV-MA  2 Seasons
# 2     September 24, 2021        2021.0  TV-MA   1 Season
# 3     September 24, 2021        2021.0  TV-MA   1 Season
# 4     September 24, 2021        2021.0  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8804   November 20, 2019        2007.0      R    158 min
# 8805        July 1, 2019        2018.0  TV-Y7  2 Seasons
# 8806    November 1, 2019        2009.0      R     88 min
# 8807    January 11, 2020        2006.0     PG     88 min
# 8808       March 2, 2019        2015.0  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8804                     Cult Movies, Dramas, Thrillers
# 8805             Kids' TV, Korean TV Shows, TV Comedies
# 8806                            Comedies, Horror Movies
# 8807                 Children & Family Movies, Comedies
# 8808     Dramas, International Movies, Music & Musicals
#
#                                             description Column13
# 0     As her father nears the end of his life, filmm...     None
# 1     After crossing paths at a party, a Cape Town t...     None
# 2     To protect his family from a powerful drug lor...     None
# 3     Feuds, flirtations and toilet talk go down amo...     None
# 4     In a city of coaching centers known to train I...     None
# ...                                                 ...      ...
# 8804  A political cartoonist, a crime reporter and a...     None
# 8805  While living alone in a spooky town, a young g...     None
# 8806  Looking to survive in a world taken over by zo...     None
# 8807  Dragged from civilian life, a former superhero...     None
# 8808  A scrappy but poor boy worms his way into a ty...     None
#
# [8809 rows x 13 columns]

# %%
# =====================================================
# CONNECT TO AZURE ML
# =====================================================

from azureml.core import Workspace, Dataset

subscription_id = 'be34845d-449d-4f47-89be-d6776438dd0e'
resource_group = 'cmr'
workspace_name = 'cmrmlo'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='netflix')

# IMPORTANT LINE 👇
df = dataset.to_pandas_dataframe()

print("Dataset Loaded Successfully")
print("Shape:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 24
#      17 from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
#      19 # =====================================================
#      20 # DATA PREPARATION
#      21 # =====================================================
#      22
#      23 # Drop unnecessary column if exists
# ---> 24 if 'Column13' in df.columns:
#      25     df.drop(columns=['Column13'], inplace=True)
#      27 # Fill missing values
#
# NameError: name 'df' is not defined
